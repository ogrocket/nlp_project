# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import nltk

# %%
data = pd.read_csv('C:\\Users\\user\\Documents\\GitHub\\nlp_project\\data\\test_questions.csv')

# %%
data['question1'] = data['question1'].str.lower()
data['question2'] = data['question2'].str.lower()
data.head(15)
# Out:
#     id  qid1  qid2                                          question1  \
# 0    0     1     2  what is the step by step guide to invest in sh...
# 1    1     3     4  what is the story of kohinoor (koh-i-noor) dia...
# 2    2     5     6  how can i increase the speed of my internet co...
# 3    3     7     8  why am i mentally very lonely? how can i solve...
# 4    4     9    10  which one dissolve in water quikly sugar, salt...
# 5    5    11    12  astrology: i am a capricorn sun cap moon and c...
# 6    6    13    14                                should i buy tiago?
# 7    7    15    16                     how can i be a good geologist?
# 8    8    17    18                    when do you use シ instead of し?
# 9    9    19    20  motorola (company): can i hack my charter moto...
# 10  10    21    22  method to find separation of slits using fresn...
# 11  11    23    24        how do i read and find my youtube comments?
# 12  12    25    26               what can make physics easy to learn?
# 13  13    27    28        what was your first sexual experience like?
# 14  14    29    30  what are the laws to change your status from a...
#
#                                             question2  is_duplicate
# 0   what is the step by step guide to invest in sh...             0
# 1   what would happen if the indian government sto...             0
# 2   how can internet speed be increased by hacking...             0
# 3   find the remainder when [math]23^{24}[/math] i...             0
# 4             which fish would survive in salt water?             0
# 5   i'm a triple capricorn (sun, moon and ascendan...             1
# 6   what keeps childern active and far from phone ...             0
# 7           what should i do to be a great geologist?             1
# 8               when do you use "&" instead of "and"?             0
# 9   how do i hack motorola dcx3400 for free internet?             0
# 10  what are some of the things technicians can te...             0
# 11             how can i see all my youtube comments?             1
# 12            how can you make physics easy to learn?             1
# 13             what was your first sexual experience?             1
# 14  what are the laws to change your status from a...             0

# %%
ps = PorterStemmer()
data['question1'] = data['question1'].astype(str).str.split()
data['question2'] = data['question2'].astype(str).str.split()
data.question1.apply(lambda x: [ps.stem(word) for word in x])
data.question2.apply(lambda x: [ps.stem(word) for word in x])
# Out:
# 0        [what, is, the, step, by, step, guid, to, inve...
# 1        [what, would, happen, if, the, indian, govern,...
# 2        [how, can, internet, speed, be, increas, by, h...
# 3        [find, the, remaind, when, [math]23^{24}[/math...
# 4           [which, fish, would, surviv, in, salt, water?]
#                                ...
# 99991          [how, did, you, come, out, of, depression?]
# 99992         [is, the, conjur, base, on, a, true, story?]
# 99993    [what, are, the, entrepreneuri, opportun, that...
# 99994    [which, is, the, best, countri, to, do, an, ms...
# 99995    [how, can, you, know, when, someon, love, you,...
# Name: question2, Length: 99996, dtype: object

# %%
data
# Out:
#           id    qid1    qid2  \
# 0          0       1       2
# 1          1       3       4
# 2          2       5       6
# 3          3       7       8
# 4          4       9      10
# ...      ...     ...     ...
# 99991  99991  198420  198421
# 99992  99992  198422  198423
# 99993  99993  198424  198425
# 99994  99994  198426  198427
# 99995  99995  198428  198429
#
#                                                question1  \
# 0      [what, is, the, step, by, step, guide, to, inv...
# 1      [what, is, the, story, of, kohinoor, (koh-i-no...
# 2      [how, can, i, increase, the, speed, of, my, in...
# 3      [why, am, i, mentally, very, lonely?, how, can...
# 4      [which, one, dissolve, in, water, quikly, suga...
# ...                                                  ...
# 99991      [how, can, i, come, out, of, my, depression?]
# 99992        [is, conjuring, based, on, a, true, story?]
# 99993  [what, business, opportunities, may, arise, as...
# 99994  [which, country, is, best, for, ms, in, mechan...
# 99995  [how, would, you, know, someone, really, loves...
#
#                                                question2  is_duplicate
# 0      [what, is, the, step, by, step, guide, to, inv...             0
# 1      [what, would, happen, if, the, indian, governm...             0
# 2      [how, can, internet, speed, be, increased, by,...             0
# 3      [find, the, remainder, when, [math]23^{24}[/ma...             0
# 4        [which, fish, would, survive, in, salt, water?]             0
# ...                                                  ...           ...
# 99991        [how, did, you, come, out, of, depression?]             0
# 99992   [is, the, conjuring, based, on, a, true, story?]             1
# 99993  [what, are, the, entrepreneurial, opportunitie...             1
# 99994  [which, is, the, best, country, to, do, an, ms...             1
# 99995  [how, can, you, know, when, someone, loves, yo...             0
#
# [99996 rows x 6 columns]

# %%
X = data.drop(['is_duplicate'], axis=1)
y = data['is_duplicate']
X, X_test, y, y_test = train_test_split(X, y, test_size=0.4, random_state=241)
